# %% [markdown]
# # Spoting Trending Topics in Scientific Research with Latent Dirichlet Allocation
#
# For this week's challenge I decided to put some effort towards finding a novel text dataset and dabble in a little data mining. After bumming around the internet for a while I found my target: **Nature.com**
#
# As far as I know nature.com does not provide any API service for programmatically accessing their content. While they have been nice enough to make some paper "open access", which means they are free to download as a PDF or view in browser as html, there's no way I am gonna point click drag copy paste through at least a hundred of webpage to get the volumn of data I would like for this notebook.
#
# Fortunately, python is good for more than data analysis.
#
# And with a url as straight forward as this:
# `https://www.nature.com/search?article_type=protocols,research,reviews&subject=biotechnology&page=3`
# who needs an api?
#
# There are two python files in this folder that I used to scrape research papers off nature.com for use in the this notebook's dataset.
#
# The first script, `collect-article-html.py`, plugs different [keywords](https://www.nature.com/subjects) in the `&subject=` placeholder in the url and goes through the first eight pages of search results. Each search result page's html is loaded into an html parser (lxml) and the link and title for all 25 articles on the results page is accessed through the xpath for their respective html elements. All article links found are followed and the raw page html for the research paper document is saved in a database (mysql) along with the articles title, date, etc.
#
# I ran this `collect-article-html.py` repeatedly across 32 different searchable keywords and in a few hours pulled down over 3000 research papers.
#
# The second script, `process-html.py`, pulls the raw html for every article downloaded. Filtering the research paper text out of the html document proved easier than I expected. I used the BeautifulSoup4 library to removal all the html tags and then with just the page text leftover it was as easy as telling python to only keep the text after the "Abstract" substring and before the "References" substring. Additional text preprocessing was doing in this script, removing all special characters, numbers, and excess whitespace.
#
# I have compiled a data set of over 3000 research papers across 32 different searchable topics from nature.com.
# Webscraping.
# Sql.
# So much information. So much scientific information.
# Here I will create a tool that can be used to summarize the key words that are being used in recent research accross 32 different fields.

# %%
import sqlite3
import pandas as pd
from gensim import corpora, models, similarities
import nltk
from collections import Counter

# %%
conn = sqlite3.connect('nature_articles.db')
cursor = conn.cursor()
num_articles = cursor.execute('SELECT count(distinct title) FROM articles WHERE wc > 1500;').fetchall()[0][0]
print('Number of unquie articles in dataset: ', num_articles)

df = pd.read_sql_query("SELECT distinct(title), text, url, journal, date FROM articles WHERE wc > 1500 ORDER BY random();",
                       conn)
df.head()
# Out:
# Number of unquie articles in dataset:  3147
#                                                title  \
# 0  Ratiometric fluorescent probe with AIE propert...
# 1  Hypoxia ameliorates intestinal inflammation th...
# 2  Clinico-biological significance of suppressor ...
# 3  Decreased long-chain acylcarnitines from insuf...
# 4  Response inhibition in Parkinsonâ€™s disease: ...
#
#                                                 text  \
# 0  hydrogen peroxide ho plays a key role in the p...
# 1  hypoxia regulates autophagy and nucleotide bin...
# 2  suppressor of cytokine signaling socs protein ...
# 3  increasing evidence shows that metabolic abnor...
# 4  parkinsons disease is a neurodegenerative diso...
#
#                                                  url                  journal  \
# 0  http://www.nature.com/articles/s41598-017-07465-5       Scientific Reports
# 1  http://www.nature.com/articles/s41467-017-00213-3    Nature Communications
# 2  http://www.nature.com/bcj/journal/v7/n7/full/b...     Blood Cancer Journal
# 3  http://www.nature.com/articles/s41598-017-06767-y       Scientific Reports
# 4   http://www.nature.com/articles/s41531-017-0024-2  npj Parkinson's Disease
#
#              date
# 0  04 August 2017
# 1    24 July 2017
# 2    28 July 2017
# 3  04 August 2017
# 4    07 July 2017

# %%
title, subject, article = cursor.execute("SELECT title, topic, text FROM articles ORDER BY random() LIMIT 1;").fetchall()[0]
print("\n", title)
print("\nSubject:", subject)
print("\n\t", article)
# Out:
#  Tauroursodeoxycholic acid enhances the development of porcine embryos derived from  -matured oocytes and evaporatively dried spermatozoa
#
# Subject: cell-biology
#
# 	 evaporative drying ed is an alternative technique for long term preservation of mammalian sperm which does not require liquid nitrogen or freeze drying equipment but offers advantages for storage and shipping at ambient temperature and low cost however the development of zygotes generated from these sperms was poor here we demonstrated that the supplementation of tauroursodeoxycholic acid tudca an endogenous bile acid during embryo culture improved the developmental competency of embryos derived from in vitro matured pig oocytes injected intracytoplasmically with boar ed spermatozoa by reducing the production of reactive oxygen species the dna degradation and fragmentation and the expression of apoptosis related gene bax and bak and by increasing the transcription of anti apoptosis gene bcl xl and bcl furthermore tudca treatment promoted the blastocyst quality manifested by the total cell numbers and the ratio of inner cell mass taken together our data suggest that evaporative drying would be a potentially useful method for the routine preservation of boar sperm in combination with further optimization of subsequently embryo culture conditions introduction long term preservation of mammalian sperm has widespread applications in medicine and agriculture including facilitating treatment of human infertility and fertility preservation for male cancer patients artificial insemination and thus genetic improvement of livestock conservation of endangered species and maintenance of genetic diversity while cryopreservation of mammalian sperm in liquid nitrogen ln has been successfully employed the ability to preserve sperm at much higher temperatures ideally at ambient temperature is preferred for a number of reasons it would dramatically reduce the storage expenses facilitate sample transport while reducing associated costs and prevent cross contamination between samples stored in ln intracytoplasmic sperm injection icsi an in vitro fertilization procedure in which a single sperm is injected directly into an egg has truly revolutionized not only the treatment options for couples with impaired semen quality and those with both obstructive and non obstructive azoospermia but also the methods of long term sperm storage which just need to protect sperm dna from physical damage irrespective of sperm motility or integrity of sperm membrane correspondingly the new approaches such as freeze drying and evaporative drying can long term preserve mouse spermatozoa without using ln or dry ice for storage and transportation furthermore the method of evaporative drying also has an advantage over that of freeze drying since the former does not need freeze drying apparatus during sample preparation however whether the method of evaporative drying available for practical use in other animals especially in swine which serves as a well recognized model for biomedicine research needed further studies preimplantation embryos are extremely sensitive to oxidative stress for a rapid growth and differentiation embryos need to produce more energy through electron transport chain in the mitochondria with atp production reactive oxygen species ros are also created as by products in the mitochondria in the normal physical condition the production of ros is sensitively controlled by the balance of oxidizing and reducing substances and these related enzymes accumulating evidence has shown that imbalance of oxidation and reduction leads to oxidative stress which causes the developmental arrest physical dna damage impaired expression profile of several anti and pro apoptotic members of the bcl family apoptosis and embryo fragmentation thus ros homeostasis is one of the key factors to keep embryo healthy on the other hand tauroursodeoxycholic acid tudca is an endogenous bile acid synthesized in the liver conjugation pathway of ursodeoxycholic acid udca which is an fda approved molecule widely used in treatment of liver diseases and served as a potent inhibitor of apo ...

# %%
subjects = cursor.execute("SELECT distinct topic FROM articles;").fetchall()
print("Subjects in dataset:\n")
for s in subjects:
    print('\t',s[0])
# Out:
# Subjects in dataset:
#
# 	 biotechnology
# 	 anatomy
# 	 anthropology
# 	 physics
# 	 psychology
# 	 mathematics-and-computing
# 	 computational-biology-and-bioinformatics
# 	 ecology
# 	 cell-biology
# 	 microbiology
# 	 biogeochemistry
# 	 zoology
# 	 climate-sciences
# 	 neuroscience
# 	 genetics
# 	 cancer
# 	 plant-sciences
# 	 immunology
# 	 chemical-biology
# 	 chemistry
# 	 evolution
# 	 stem-cells
# 	 ocean-sciences
# 	 diseases
# 	 molecular-medicine
# 	 engineering
# 	 materials-science
# 	 nanoscience-and-technology
# 	 drug-discovery
# 	 philosophy
# 	 business-and-industry
# 	 developmental-biology

# %%
def render_topics(subjects, num_topics=3, stem=False, filter_n_most_common_words=500, num_words=30):
    if isinstance(subjects, str):
        df = pd.read_sql_query("SELECT distinct(title), text FROM articles WHERE wc > 1500 and topic = '{}';".format(subjects),
                               conn)
        
    
    else:
        df = pd.read_sql_query("SELECT distinct(title), text FROM articles WHERE wc > 1500 and topic IN {};".format(subjects),
                               conn)
    
    docs = df['text'].values
    split_docs = [doc.split(' ') for doc in docs]
    doc_words = [words for doc in split_docs for words in doc]
    wcount = Counter()
    wcount.update(doc_words)
    stopwords = nltk.corpus.stopwords.words('english') + ['introduction','conclusion'] # filter out terms used as section titles in most research papers
    for w, _ in wcount.most_common(filter_n_most_common_words):
        stopwords.append(w)
        
    if stem == True:
        docs = [stem_and_stopword_filter(doc, stopwords) for doc in docs]
    else:
        docs = [stopword_filter(doc, stopwords) for doc in docs]
    dictionary = corpora.Dictionary(docs)
    corpus = [dictionary.doc2bow(doc) for doc in docs]
    lda_model = models.LdaMulticore(corpus, id2word=dictionary, num_topics=num_topics)
    topics = lda_model.show_topics(formatted=False, num_words=num_words)
    
    print(subjects)
    
    for t in range(len(topics)):
        print("\nTopic {}, top {} words:".format(t+1, num_words))
        print(" ".join([w[0] for w in topics[t][1]]))
        
    
        
        
def stem_and_stopword_filter(text, filter_list):
    stemmer = nltk.stem.snowball.SnowballStemmer('english')
    return [stemmer.stem(word) for word in text.split() if word not in filter_list and len(word) > 2]

def stopword_filter(text, filter_list):
    return [word for word in text.split() if word not in filter_list and len(word) > 2]

# %%
# specific subjects to analyze for topics as a tuple of strings
# ie subjects = ('philosophy', 'nanoscience-and-technology', 'biotechnology')
subjects = ('philosophy')

render_topics(subjects, num_topics=9, stem=False, filter_n_most_common_words=500)
# Out:
# philosophy
#
# Topic 1, top 30 words:
# hermeneutical identity sloterdijk markets seen genotype advance heidegger fascism forces faith crisis perspective mean hermeneutics genocide event remains nothing christ actual central action calls show theatre finally autonomy past follows
#
# Topic 2, top 30 words:
# theatre particularly ukk suggest later past immanence suggests provides abstract markets several existing debate elements neoliberal worlds cognitive samples actors examples private perspective attention stakeholders associated today identification taken kantian
#
# Topic 3, top 30 words:
# theatre object ssh climate internal consciousness genotype ontological standard collaboration far external established transcendence basic contemporary involves private act understood economic field funding traits every identification remains suggest concern takes
#
# Topic 4, top 30 words:
# faith event holy sacred advance markets occurs neoliberal interior sloterdijk never forces seems theological politics central narrative idol heidegger address practices contemporary neoliberalism comes act perspective calls turn importance size
#
# Topic 5, top 30 words:
# christ interior hope ssh funding peace child importance collaboration projects integration contemporary heidegger issue acts climate actual ideas around exist impact later today basic address org understood empirical views final
#
# Topic 6, top 30 words:
# pgt deliberation diseases consumers www csp com instance impact christ greater laws technologies aim national providers allow offer http appropriate light associated options participation computing security stakeholder ipcc action climate
#
# Topic 7, top 30 words:
# mohr replication advance structure included size muslim immanence essential greed main described attitudes held genotype seems computing cognitive stakeholders published additional linguistic greater lines identity interior particularly technology private traits
#
# Topic 8, top 30 words:
# greed pgt kantian consumers ses diseases economic seen internal external aim views environment essential sample models rational acts involves effects direct follows offer standard understood unethical greater attitudes third deliberation
#
# Topic 9, top 30 words:
# law minors ngs registered technologies children principles thoughts projects biobanking instance controlled child associated samples rational provides essential particularly deliberation benefits requirements identify ipcc status transcendence population commitment ifs screening

# %%
render_topics(('mathematics-and-computing','computational-biology-and-bioinformatics','nanoscience-and-technology'),
               num_topics=9, stem=False, filter_n_most_common_words=500)
# Out:
# ('mathematics-and-computing', 'computational-biology-and-bioinformatics', 'nanoscience-and-technology')
#
# Topic 1, top 30 words:
# voltage film pulse tdp devices crystal medium required mechanism compounds core resistance components scattering find concentrations measurement green furthermore profiles reaction overall limited cellular ras map way compound zero follows
#
# Topic 2, top 30 words:
# graphene csp clinical infection panel datasets membrane detected dynamic crystal measure cycle variables loss term diseases end connectivity global whereas paper green mechanical medium sensitivity clear neural mass years alignment
#
# Topic 3, top 30 words:
# events metal connectivity scattering treated mice sleep pressure detected paper stability smaller graph consistent duration global errors map fluorescence end impact datasets relatively index common amount dynamic identify solid probe
#
# Topic 4, top 30 words:
# pairs rna term detected neural strategy way sequencing five probe snps involved hence errors approaches risk voltage identify mixed reaction graphene regulatory profiles age estimate temporal core coupling zero obtain
#
# Topic 5, top 30 words:
# fractal scaling iii infected likely stress extracted datasets moreover profiles hand mice way tumor stability applications validation required dynamic delay global age condition developed added interface plot threshold strategy infection
#
# Topic 6, top 30 words:
# boundary lattice index critical coupling dimensional variants paper indicate pressure five reference climate chain mice cycle risk cost zero overall furthermore hence whether impact memory moreover map strategy curves term
#
# Topic 7, top 30 words:
# resonance variables graph tdp sers cycle tumor feo fluorescence coupling problem spectrum rna events components stability theta probe algorithms snps mechanism computational membrane might peaks devices identify smaller finally profiles
#
# Topic 8, top 30 words:
# mutation sleep bcl stress regulatory edges tfs solutions associations computational membrane global smaller obtain components likely link another ground crystal variables connectivity directly output furthermore general dynamic diseases nanoparticles seed
#
# Topic 9, top 30 words:
# infected cetp theta infection thermal gap spectral surfaces orientation mechanism boundary measure transmission threshold dependence membrane period stability lncrnas polarization stimulation terminal interface overall diffusion dimensional temporal transport thickness general

# %%
subjects = cursor.execute('SELECT distinct topic FROM articles;').fetchall()

for s in subjects:
    render_topics(s[0], num_topics=9, stem=False, filter_n_most_common_words=500) 
    print('==================================================================================================')
# Out:
# biotechnology
#
# Topic 1, top 30 words:
# shell tanc paper flies fluorescent domain index insulin success pha cellulose maximum dark indicates optical prexpress included sea honey correlation pre honeys glucose reduction ihc pids immune scattering removed ils
#
# Topic 2, top 30 words:
# opsin tobacco device leaves normal accumulation opnmw infected retention peg parkinsons viral form cone loss cohort targeted common bar compounds acids pre age fatty ratios reduction amount correlation likely stem
#
# Topic 3, top 30 words:
# ngo nps ago cpg peg mir mirna slt dcas flakes needle cpeg plasmid shaped ola tumor end antigen device cycle infected patient systems retention targeted plates primers dga salmonella membranes
#
# Topic 4, top 30 words:
# phya ecm synthesis ago phyb exon pathogenic seed seq accumulation epa luciferase acids tanc csps score variant double point inflammatory dha generation stem mrna imaging signaling grown plate infected tobacco
#
# Topic 5, top 30 words:
# copulation pase success mir agnps zdiii ago cpgs flies silver amniotic mirna loci white male pha bar substrate glucose differentially indicates matrix infected examined mrna patient phyb showing mixture immune
#
# Topic 6, top 30 words:
# regulation microbial mirna receptor slt breast immune antigen gut generation profiles populations transcriptome constructs patterns components crispr produced differentially individuals examined mir gfp bantu parameters membranes score major functions bmdopr
#
# Topic 7, top 30 words:
# repeats ssp zdiii chloroplast phylogenetic crispr hbcag primers halleri tcp niv gemmifera six vaccination vlps effective petraea produced viral root induction hap pre cases terminal final fragment lyrata iron approximately
#
# Topic 8, top 30 words:
# contact impact slt spreading membranes slp antigen muscle active srta aniso ola salmonella measurements substrate mechanism shs compounds cross endothelial state showing pcz dga amount prior strain antibodies included along
#
# Topic 9, top 30 words:
# mesh dms populations wheat agnps carbon dex ngo substrates mouflon copulation hydrogels gsk degradation rates nds succinate electrode peg cold hydrogel mrna sheep tcp reduction oxygen normal shell components mdd
# ==================================================================================================
# anatomy
#
# Topic 1, top 30 words:
# hyal mcs nrp bioconstructs ang muscles deficiency joint vml muscs saline cortical enhanced nedd kidney assessed indicates mob trpc new available amplitude depth week alpha collagen direct axons molecular articular
#
# Topic 2, top 30 words:
# brdu input irf output threshold nedd offspring itk testes rat alpha curve resolution niacin larger nis infected recorded decrease confirmed olfactory power tumour insulin washed concentrations means colon greater available
#
# Topic 3, top 30 words:
# filling effector pgc trpc lkb infected spf vertical alveolar foxp hdac signalling cmv foxo scene horizontal knee kidney rankl hcv dogs case contact properties healthy maturation means plots copd pupil
#
# Topic 4, top 30 words:
# leptin hyal offspring interaction axonal tfh cicf tet hes huvecs fak nrp diluted fed skap clusters cic gfp major reading diet direct neural strains cortical properties huvec fibrosis lfa concentrations
#
# Topic 5, top 30 words:
# hair release artinm bladder tumour lkb cancer reading score distractor female effector investigated threshold ova stage cpg epilation foxp lymph upon types free death health ccr nlrp glomeruli act schwann
#
# Topic 6, top 30 words:
# oxa cgl pupil mask pin bladder evoked lfa semac act skap gal pkc infected suppression dhc fak next direct western trpc transfected rankl evidence signalling hyal nlrp enhanced confirmed pressure
#
# Topic 7, top 30 words:
# tail hes hat ppar mscs nlrp mechanical mmp spine dogs cldn power evidence pain cpg clic eye surgery inflammasome colon form alpha female week clics hydrogel plate foxp saline corresponding
#
# Topic 8, top 30 words:
# pak distance input eyes effector antigen cone output gfp lines shape central ccr ankle assay synuclein added perceived cancer joint example caused skap reading wild likely cgl prior months plots
#
# Topic 9, top 30 words:
# tet search distractor etoh boo distance sigm bladder vwm rako thymocytes properties pressure depth hydrogel nedd block receptors induction mepscs upper trial cue features bpv accuracy moreover cued new dorsal
# ==================================================================================================
# anthropology
#
# Topic 1, top 30 words:
# subject ancestral frequencies enamel content day men motion teeth face particularly vocal geographic protein allele rank resulting materials communities software event pleistocene plant means represented kin complete manganese oil current
#
# Topic 2, top 30 words:
# orbital haplotypes zinc motion domestic temporal mitochondrial plant protein applied analyzed sapiens risk comparison ancestral component section specimen gamma ratio fitness image face ape system functional head still cranial highest
#
# Topic 3, top 30 words:
# american manipulation months infants temperature historical taken demographic play sampling objects sharing temporal trees forest environments correlation location ancestral distances great competition orbital object light geographic despite adults types snps
#
# Topic 4, top 30 words:
# tasr theological transition neandertal fitness men account china facies asia palaeolithic means face living located pleistocene domestic centrality cranial fossils measures teeth complete measurements degree access composition types ratio layers
#
# Topic 5, top 30 words:
# palaeolithic foot men rank experiments experiment composition impact experimental layers risk estimate software demographic old throwing agent account fitness especially comparison location competition agents measurements reproduction lifespan dating plant birth
#
# Topic 6, top 30 words:
# facies manganese orbital agents gesture demand lbk palaeolithic competition ancestries agent degree focal play prevalence dating lateral radiocarbon angle evolved resources layers applied published risk baka asia ability suggesting dispersal
#
# Topic 7, top 30 words:
# moral judgments sanctions sango sakura discourse men ancestries focal eggshell adults mitochondrial american round composition event self behavior public cooperativeness plants account negative genyornis care sub orbital make dating family
#
# Topic 8, top 30 words:
# rank vocal head gesture manipulation complexity infants muscles transition allele functional joint subject discourse understanding contexts state findings foot living particularly wookies elo scores later followed lack parameters self haplotypes
#
# Topic 9, top 30 words:
# enamel sub mitochondrial vocal asia complete dispersal distances infant helpers correlation experimental ancestries subjects sherpas languages eurasian component conducted facies italian trees parameters directly showing software estimates comparison general main
# ==================================================================================================
# physics
#
# Topic 1, top 30 words:
# node illumination tio random zno calculations reaction links entropy annealing curves enhanced chain group algorithm green particular enhancement disturbance mos solar visible activity mixture follows tie attack finally hence resulting
#
# Topic 2, top 30 words:
# dna ectoine fatigue pores tlr droplet atom stress response gradient scaling cuzr photons feature estimated pump limited fractal directly location spectroscopy decrease acoustic path reaction tuning located consistent node output
#
# Topic 3, top 30 words:
# wall gmr pores activity anisotropy gradient solar double whole polarized electrons fmn profile refractive helical rfk upon module electronic configuration bilayer discussed decrease elements either group lipid highly bias composition
#
# Topic 4, top 30 words:
# lsmo helical trivial disorder probes quasi orientation disordered qsh oxygen negative spectroscopy technique transitions entropy composition bsto lnmm variation antenna resulting reaction bilayer consistent mass cofe illumination carried measure plasma
#
# Topic 5, top 30 words:
# nanoparticles sers prilocaine magnon scaling proton silver mass links dirac boundaries tio gqd node chiral robustness solar disturbance fractal sampling decrease carbon located glucose sem output coating achieved orientation enhancement
#
# Topic 6, top 30 words:
# qudit levels plant photons tradd pulses superconducting entanglement pollinator coupled particular lsmo key sampling extinction decrease corresponds pollinators pump pyrroline incident numerical protein output represents functional calculations across boson terms
#
# Topic 7, top 30 words:
# raman zenv dirac axl additional group zone magnon pump fixed fese resulting refractive condition limited orientation curves reduced directly phonon domains experimentally scan competitor finally stability spectroscopy sensitivity strategies incident
#
# Topic 8, top 30 words:
# vortex acoustic ionization gqd mfm nps performance links probes glucose sers mixture double enhancement metallic silver seop boundaries relaxation configuration thick momentum studied occurs grain represents echo main good bias
#
# Topic 9, top 30 words:
# magnon lnmm dirac relaxation phonon measure electronic elements fractal investigated bands momentum physical consistent means incident stage focal presented discussion distortion negative cooling main alo vector specific raman respect geometry
# ==================================================================================================
# psychology
#
# Topic 1, top 30 words:
# anger engagement integration defined multisensory log alcohol intention controls index applied amplitudes schizophrenia rule apathy fixations igd health towards least punishment means men volume feedback investigate facial background informed aud
#
# Topic 2, top 30 words:
# nrem implicit coherence report knowledge vwm igd period university patterns volume speech fit explicit ptsd tone search functions impact tactile frontal differ rts suggesting note degree aud parietal psychological pairs
#
# Topic 3, top 30 words:
# attitude tom intervention errors person impact orientation females arithmetic schizophrenia rts investigate reading affective work videos rest note indicates targets support males half patterns detection elements delay anxiety depth nogo
#
# Topic 4, top 30 words:
# rake rats anger engagement infants tool gaze testosterone obtain cued fmri examined intervention food manipulation violent sessions states distraction correct placed required recorded reading additional vstm rat least person last
#
# Topic 5, top 30 words:
# kiss kissing turning nrem school intention tpj chronotype happiness males grades audio handedness involved tactile targets rts corrected volume investigated ratio mtc humans recipients half females followed suggested offer induced
#
# Topic 6, top 30 words:
# child depth csf old prosocial selected tactile asd young adhd towards music retest observational pre note western controls placebo index reading tone least direct short mixed suggesting followed agent term
#
# Topic 7, top 30 words:
# attend feedback feature videos near colour health input observers variable resolution posterior demonstrated tone methylation expressions significance conflict terms stimulation anxiety competition punishment treatment parietal underlying version person generated females
#
# Topic 8, top 30 words:
# input events gender gaze video common personality amplitudes valence locations functions rpe types rule speech identified health adaptation account informed fmri demonstrated represent many people interest variable fit anxiety predictive
#
# Topic 9, top 30 words:
# alcohol rest gria volume trace sucrose controls sizes csf responding addressee dependent estimate pointing outcomes disorder sessions correct index old mixed music background lick many towards oriented punishment health condemnation
# ==================================================================================================
# mathematics-and-computing
#
# Topic 1, top 30 words:
# speed spin tumor vertex neurons pattern pollution communities msns dynamic view bifurcation curve steps developed links vertices highly path mixed connectivity another characteristics direction research correction furthermore distributions procedure ground
#
# Topic 2, top 30 words:
# heat phasor trade plot pixels empirical infection fluid impact interactions variation feasible users drug shocks domain entropy concentration molecules reduced index upper procedure height trees social final metrics components world
#
# Topic 3, top 30 words:
# event events cover steps tissue index influenza risk score tree topological research detection background scores registration previously growth class forest open procedure another world components characteristics fact allows include showed
#
# Topic 4, top 30 words:
# band exclusion pulse laser infection peer topological nodule pool curvature interval punishment angle fraction directly interest part wavelength minimum index reconstruction solid estimate limit common speed source moreover classes radiation
#
# Topic 5, top 30 words:
# species paths coexistence fraction cooperation molecules inequality whether connectivity sub path interval previously influential correction measurement machine theory clinical moreover laminate research domain equilibrium influence reaction need detected intraspecific position
#
# Topic 6, top 30 words:
# sensitivity voltage paths oscillators entropy tuned pareto measurement coil equivalent array coupled radiation protocol coupling diversity trade spin weight respect mcspsospea participants rectangular fact path risk influence pattern achieved complexity
#
# Topic 7, top 30 words:
# tpa transition weight treatment generation stability class coupling oscillators particle dimension influence randomly memory machine reduced clot gaussian scheme binding panel equal fiber equivalent molecules plasmin fire fibrin part distributions
#
# Topic 8, top 30 words:
# bob particle antigenic scores true developed seed directly domain score interactions dependent dimension charge expected tkv consistent particles machine device secret correction scheme clinical ground solitons tissue estimation let called
#
# Topic 9, top 30 words:
# solitons modes subnetworks stability plane pulse soliton symmetric subnetwork structural paths tree velocity figs equivalent mixed world part laser reduced seed tumor risk minimum directly clinical generation cover trees vertices
# ==================================================================================================
# computational-biology-and-bioinformatics
#
# Topic 1, top 30 words:
# clear flss susceptible seq tumor sre resistant iii day wide differentiation stage family library hla suggest density pdb reference developed libraries still evidence relatively processes software furthermore peptide differential motifs
#
# Topic 2, top 30 words:
# bcl trap exon rnq nats methylation bar tfs bound climate pdb blocks affinity patient developed sup aggregates differential promoter snvs scores gram tumor means pai identification tools breast threshold pcr
#
# Topic 3, top 30 words:
# assay hla peptide delay driving hand neuron epac mechanical series duration efficiency bifurcation temporal nats transition firing iii excitability noise curves condition curve sre expressing fnirs days visual degree differentiation
#
# Topic 4, top 30 words:
# ssp genomes enzyme enzymes knotoid predictions mzbl predict revealed weight graph chain genomic motifs computational tumor exon conserved evidence profile hand better patient breast salt algorithms variables sre glut halleri
#
# Topic 5, top 30 words:
# dyrkb stiffness strains ras place rnq climate gfp family native bcl impact formation lung motifs right ase stress tfs enrichment wild folding neuron clear graph tissues disulfide reference prevalence cycle
#
# Topic 6, top 30 words:
# ift behavior fluorescence dgk flss critical visual folding map task disulfide bound solution noise inhibition condition representation best snp period processes lifespan wild node exon cleavage exons fraction part signaling
#
# Topic 7, top 30 words:
# insulin methylation hsa food stress solution via note best dyrkb inhibition cycle distributions iii extracted ras software transfer moreover six gfp better serum muscle next means component whereas curve nanog
#
# Topic 8, top 30 words:
# tanc task creb ring bump food condition inhibition participants assembly body memory eta software weight wild loop circuit seq chain neuron mutants representation context simulated hsa liver delay curve domains
#
# Topic 9, top 30 words:
# sleep caribaeorum subjects mrnas signaling transcripts extracted lncrna trap presented reference assay predict doxorubicin fit might profile neuron stage years identification recent visual prior revealed times demonstrated best via compound
# ==================================================================================================
# ecology
#
# Topic 1, top 30 words:
# larvae acetoin tadpoles dom pond properties condition canopy noctiluca phase induced much probability dec prior plantarum pcr numbers sources salt followed affect components way larval complexity support gut wfps terms
#
# Topic 2, top 30 words:
# tadpoles sharks cohort coating reef inorganic treated zoospore parameter load infected testosterone pga fungicide approach ponds clear breeding followed dataset shark hybrid types niche transposase support particular association extinction estimates
#
# Topic 3, top 30 words:
# disease breeding phase risk empirical conservation zone degree complexity noctiluca scales ability ref random spring open tests mixed sex end central map aphid salinity pheromone types process defined much particularly
#
# Topic 4, top 30 words:
# lake pvd trade krill condition drought degree river trawling bidirectional competition resulting comparison social shocks intensity salinity island benthic precipitation types additional probability http temporal process way exposure grassland variability
#
# Topic 5, top 30 words:
# pga aphid clusters growing aphids predation risk amf male dom vegetation seabirds cues river images echoes image cotton explained furthermore part association whole productivity sex map process leaves reproductive resources
#
# Topic 6, top 30 words:
# dms sharks compounds fruit choice gut deep reef white sources salinity suggesting larvae expression way short added numbers tissue spot locations competition part infected regression core variance predation probability isotope
#
# Topic 7, top 30 words:
# chl exposure sound transgenic larvae acetoin noise gasoline derived infected ice deposition temperatures spring components periods particle ijs river approach noctiluca http regression caused prior crop image seasonal complex amf
#
# Topic 8, top 30 words:
# coating soc guppies inorganic terrestrial pga particles predation properties disturbance northern sulfide coal periods hosts tio layers rhizosphere solution much dom phases process ice lake resources vegetation national derived microbiome
#
# Topic 9, top 30 words:
# transposase reads disturbance extinction iodoindole genome particle pollinator numbers disease rrna empirical terrestrial ethanol amplicon expression ambient abundances state turnover gradient island probability daily months locations airborne approach features elevation
# ==================================================================================================
# cell-biology
#
# Topic 1, top 30 words:
# lecs ddr lnc lfar ndrg dsg myb substrates hhari shrna lung fusion emt myo functional fibrosis weeks lens cadherin art models early domains macrophages pin primers germany promotes showing transcriptional
#
# Topic 2, top 30 words:
# vegf ado himf kinetochore crystals replication bont waspkko termini nps purchased angiogenesis cdkal ccp macrophages knockout hhari inflammation kinetochores shaped fecd trxr redd aurora functional early four percentage invitrogen lung
#
# Topic 3, top 30 words:
# dph elp trpc cftr myospryn act adipocytes hair sensitivity fasn heart kinetochores bat regions functional epilation gal corresponding taken genetic lateral apb four redd sensitive since atf aurora oxidative standard
#
# Topic 4, top 30 words:
# hhari ubch collagen mkk par lkb ddr ring muc sections heart lnc pkn localization ezh energy fibroblasts burn lfar ado telomerase myb comparison sidt larvae sma metabolic nasal percentage jnk
#
# Topic 5, top 30 words:
# muc klk tert ezh plar peptide ado gli peptides recruitment gsk cleavage analysed channels molecules breast rhoa cisplatin ddr mkk novel evs thermo lysates healing multiple osteosarcoma ratio erk burn
#
# Topic 6, top 30 words:
# crystals confocal lfar rqt healthy klf would added lnc macrophages caspase reaction prdx membranes hela src lung hypoxia pvhl replication standard germany hinge bone quantification generation artinm amplification coding promotes
#
# Topic 7, top 30 words:
# scs shrna replication afm bont mtorc lsd redd cdkal cftr lps imaging lfar four mass flamindo pink sections association fecd brain mtor investigated average major burn carried pik way larvae
#
# Topic 8, top 30 words:
# trpc ndrg dga arf irs dsh mda art trib hypoxia fed energy weeks gal viability cdcpli bret starvation standard oxidative hfd cultures assessed collagen signals silencing resistance caspase supplemented multiple
#
# Topic 9, top 30 words:
# dyrkb notch mecp poglut egf rnai udp rapa rhbdl inflammation luciferase apb rwpe fusion substrates healing klf keratinocytes prostate novel prpc complexes taken shows induce stage invasion repair channels dsg
# ==================================================================================================
# microbiology
#
# Topic 1, top 30 words:
# mesh tet zdiii dms saliva mir oral arginine hbcag stress sulfide exhibited baumannii sqr intestinal subtilis profiles pna worms microbiome common pilb layer healthy pdo case blue presented included terminal
#
# Topic 2, top 30 words:
# land mrsa particles bont cfav luciferase iii hcv traf various stress chain neurons soc noctiluca distance panel microscopy blue drought lung transmission vivo sigma pixr encoding vamp layer examined cluster
#
# Topic 3, top 30 words:
# parasites hepatocystis mesh dms nox confirmed supplemented omvs diet genus products traf included hours lactobacillus genera led investigated mbt vaccination primary magnli various luciferase phases plantarum coal showing molecules gfp
#
# Topic 4, top 30 words:
# pvd hcv particles mdp chickens panel long iii influenza domain carried honeys dilution double cfav receptor form tet compounds bont tagged gel sgp secretion population exposure vector correlation upper cellular
#
# Topic 5, top 30 words:
# bont dom forest tet soc intestinal forests bbr component debris gas vamp parasites mbt rsv early encoding biomass ifn components profiles activation factor peptide carried bkv simcells genera residue possible
#
# Topic 6, top 30 words:
# rsv stc jnj lung nucleotide forest amplicon saliva pathways mrsa iav final influenza approximately cellular shotgun fatty laboratory flow common assessed together pollen diluted included dose extracts amplification dom possible
#
# Topic 7, top 30 words:
# ppm traf csfv pixr dose influenza cip flow mir dnra exhibited scid mrsa promoter pre tyr alone glucose taxa loss challenge form gas confirmed diet common nitrogen monomer protection antiviral
#
# Topic 8, top 30 words:
# fluoride cloacae slt frm salmonella pcz isg otus jnj population enzyme diet electron suggested typhimurium daf gfp compounds laboratory microscopy biomass family amf lawsone molecules oral approximately mechanism recombinant findings
#
# Topic 9, top 30 words:
# noctiluca pixr lactate pilb mtb metabolism genetic immunized burgdorferi challenge subtilis vivo macrophages microbes peptide assessed tick genera prey laboratory form vaccination intracellular products final hbcag stained furthermore recombinant terminal
# ==================================================================================================
# biogeochemistry
#
# Topic 1, top 30 words:
# dust litter root remains strain bottom induced tree intensity pulse efficiency stations bulk pga main fit optical resulting recent contents cycles many group application isoprene central second either suggested pyrite
#
# Topic 2, top 30 words:
# litter noctiluca groundwater mol pyrogenic food rain yield open chamber induced harbor spectra application topsoil decomposition nau bottom inorganic fertilizer suggested corresponding phosphorus crop atmosphere summer mainly intensity root sfgd
#
# Topic 3, top 30 words:
# discharge chl fish fractionation river group cover mol shows ion sinking least arsenic element laboratory proteins dic sensitivity substrate bars second approach selected iluc poc series local pahs weight inorganic
#
# Topic 4, top 30 words:
# nosz topsoil grsp typical demonstrated pyrogenic sequence tree usa bars yield decomposition modern denitrification minerals inorganic root dominated sulfur indicated management active followed agricultural atmosphere abundant added application cropland antimicrobial
#
# Topic 5, top 30 words:
# pga pyrite grsp root seasons application yield hair redox survey bound north expression summer nitrite fertilizer contents pool abundant arsenic proteins body cycles decomposition urea end enhanced island individual bottom
#
# Topic 6, top 30 words:
# dust pahs edge correlated element strain tropical central mol open represents recent chert followed abundant utilization productivity modern cover spatial atlantic pool bulk either database highest red cycles burial erosion
#
# Topic 7, top 30 words:
# discharge sinking plants phosphorus poc extracted bay variables spatial summer corresponding last sulfide sensitivity bulk chert relationships decomposition climatic records river patterns contrast chamber local modern events noctiluca either fungi
#
# Topic 8, top 30 words:
# fractionation patterns plants phosphorus poc membrane pahs proteins variables selected pool vertical arsenic tropical dna highly plot grassland point relationships salinity mixed overall enhanced strain supply parameter correlated inorganic limitation
#
# Topic 9, top 30 words:
# dms grassland phytoplankton tropical database cover burial loss atlantic edge north added radiocarbon modern local chert root consumption dna remains recent pyrogenic abundant dust pathway guano reservoir succinate affected sensitivity
# ==================================================================================================
# zoology
#
# Topic 1, top 30 words:
# pixr bat tail mice bats imidacloprid carp colony tmx beetles dwv dpp greater free head virus tick examined upon mechanism carried distances way apterous limited burgdorferi separate ticks signals dsrna
#
# Topic 2, top 30 words:
# call pptrpa sperm bats natal playback dietary elovl complete colony overall signals air examined mrna independent lines dogs mosquito virus bone flow black analysed pattern suggested dwv evolution loud terms
#
# Topic 3, top 30 words:
# venom ants bone sperm whales queens ant shape colony pump flow fluid immune thrips replica chambers note epithelial pressure volume affect view mice analysed broilers sediment vestalis reduction presented suggest
#
# Topic 4, top 30 words:
# rake rats reward tool sediment sponges position training right trials elovl indicates locusts dsrna aphid obtain success cotton ijs coding decrease direction pressure proportion replicates fitness last selected mmm hosts
#
# Topic 5, top 30 words:
# carp workers queen queens performance sponge rumen odour fatty pattern lac lipid ants feed sponges virgin limited physiological bars mgs decrease courtship liver generation pixr amino moreover acids family coding
#
# Topic 6, top 30 words:
# cotton dsrna metabolites rats regulated specialized leaves acids dispersal noise odour right observations leaf tail elovl way highest position kit suggested success prior lipid glucose pptrpa assay rake affected probability
#
# Topic 7, top 30 words:
# microbiota trawling grass mosquitoes dolphins proboscis parts lineage flow taxa haplotypes impact capture yellow call approximately various fungal movement immune head variables north around cotton initial upon genera affect suggest
#
# Topic 8, top 30 words:
# elovl movement yellow various garlic pattern posterior approximately evolution findings phases highest http performance reads suggests mundtii probability phenotypic moreover showing bear migration generation able breeding peak tests suh investigated
#
# Topic 9, top 30 words:
# cort rumen trials venom climate soaring formation virus hours bias air locations posterior location physiological anterior source rats dsrna reads structures suggests immune volume spatial complete direct made showing along
# ==================================================================================================
# climate-sciences
#
# Topic 1, top 30 words:
# chl mesh dms saturation gasoline age gene pdo rain upwelling month combustion benthic litter network previously known zone ozone approximately primary lead column detected coefficient individuals radiocarbon volume proteins nitrogen
#
# Topic 2, top 30 words:
# edna groundwater fluxes chl variance formation components volume ccn salinity islands methane island resources understanding snow still map violent wtp locations survey arctic five pga gradient early scales clusters antimicrobial
#
# Topic 3, top 30 words:
# islands genes ulva eddy ppm gene section cycles variance primary core medium mol island last separation volume way case oxygen second layers especially tree applied defined eddies anthropogenic chemical net
#
# Topic 4, top 30 words:
# pyrite islands genes group damage proteins oxidation bias sulfide bwet rcp medium products sequences constant made systems forcing regulation produced duration overall edna volume island droughts applied mcra five chemical
#
# Topic 5, top 30 words:
# noctiluca pga mesh salinity dms food dust plots multiple prey maize green nutrients tidal zone spring groundwater topsoil previously root fire loss treatments balance burned doc comparison stress lead gasoline
#
# Topic 6, top 30 words:
# slope map tree spruce pdo asp root fluorescence amino qinghai srdom wetland formation krill decreased wue deposition nitrogen ecosystem spores approximately emission defined cmip damage bottom applied glacier litter components
#
# Topic 7, top 30 words:
# nau tfpw gasoline droughts primary combustion methane groundwater ppm ethanol maize fuel tree group dust near might forcing indicated systems citrate contrast stress sensitivity prior deposition according wet months figures
#
# Topic 8, top 30 words:
# ppm gps vcd pwv cip tws biofilm wtp jet uptake forcing contrast tyr station methane anomaly sat tidal second formation months meteorological multi enhanced storm approximately simulated near systems better
#
# Topic 9, top 30 words:
# clusters tfpw ismr iod projections chemical edna terrestrial ecosystem ccn deposition uncertainties droughts phases urban agricultural estuary parameter cluster damage magnli combined dataset coal common fluxes hydrological scales locations seabirds
# ==================================================================================================
# neuroscience
#
# Topic 1, top 30 words:
# layer class critical firing interneurons bifurcation excitability bhb drug release work circadian cycle bifc features circuit mkk faces nacl combination points bla systems restraint transmission dose stage active stable female
#
# Topic 2, top 30 words:
# bcl mechanical scs delay cdk hand features drug mechanism perceptual open work free fmri perceived glutamate circadian dynamic denv peak iii additional bar albumin auditory stage functions movement psg resulting
#
# Topic 3, top 30 words:
# ildr mechanical delay rna epha place npy hand central cost cone hypothesis retinal background amplitude vinegar dose semac trpa glucose lines gal old choice differentiation optimal channel obese testing alternative
#
# Topic 4, top 30 words:
# sucrose glucose cluster ildr lick concentrations gria perceptual nanog msns object lactate hand another novel free differentiation water interactions mre genetic offspring central collected movement sensitivity assay measure accuracy influence
#
# Topic 5, top 30 words:
# ptx bpa parkinsons amplitude psg mre infarct bone nad whisker offspring symptoms movement derived greater dose stage black free sections nmdar cross pcr veh procedure hand dna delay volumes insulin
#
# Topic 6, top 30 words:
# insulin score tau accuracy akt vehicle mhe sarcopenia intake many required bmi orientation scores provided variants controlled process wnt mask procedure incubated mir anxiety psg emotional form mre phosphorylation activated
#
# Topic 7, top 30 words:
# block oxa uncertainty offspring dyrka acc methylation class punishment epha probability urx molecular evoked mefd income sperm mutant wild promoter functions insulin spiking ros bifurcation cycle sensitivity greater many acid
#
# Topic 8, top 30 words:
# trkb dnam income epha cpgs nmdar inequality glua variance indicates whisker schizophrenia components cfs cdk nodes available variability binding open global degree synapse npy another dna action glutamate generated genetic
#
# Topic 9, top 30 words:
# promoter nad dyrka act igg symptoms mask mechanism uas seizures cdk growth stage features bcl methylation incubated assay ring mkk patterns mitochondria abt death schizophrenia intensity tbi apoe weeks scores
# ==================================================================================================
# genetics
#
# Topic 1, top 30 words:
# renal chr bmi radiation deletion muscle tanc damage tests hkme metformin signal swb lifespan fluoride assessed expressing years socs carried muc double research candidate signals tgf mutax determine volume gsk
#
# Topic 2, top 30 words:
# ssp dga fluoride starvation flies cloacae halleri adult petraea lyrata gemmifera fetal bar absence bmi body males blocks frm termination essential plasma arabidopsis pbs deletion mhc wnt shared reverse snvs
#
# Topic 3, top 30 words:
# copulation success urx lin particle flies phewrky waspkko males lsd neurons mutax gmpal skin water female green elp wrky trap pairs opsin ros soybean apoptosis chr expected signatures motif blue
#
# Topic 4, top 30 words:
# tdp signatures gsk autophagy possible schizophrenia pkd signature abundance adult terminal metformin volumes terms overall read csps tcga receptor tests radiation traits case expected ros yfv meta cellular lsd cohort
#
# Topic 5, top 30 words:
# gsk osstrl tanc muc lps lifespan flat opsin lung arg particle chloroplast microglial diseases graph deletion scale motif waspkko interaction determine inflammation light antibody suggested targets heterozygous green cadherin prior
#
# Topic 6, top 30 words:
# drug csps ase brca mouflon sheep stable phase kgp socs gaba lsd pattern cntfr csp infection rgs males isolates possible derived phosphine differentially profiles coli tcga resistant rad daf experimental
#
# Topic 7, top 30 words:
# pilb trap eps elp sensitivity pathogenic muc transcript cntfr years dsrna process dominant production phase dga mhc splice mouflon lung investigated caused antibodies pila pno features double cad read old
#
# Topic 8, top 30 words:
# stc daf shotgun semac bmdopr dataset amplicon socs skin microbiota abundance receptor tanc metabolism shared coli qtls signals next log signatures signature traits transcriptome medium ssp water sets processes tbx
#
# Topic 9, top 30 words:
# cadherin muc twist stc nsclc chr lifespan cpg cntfr cxcr ccn radiation cohort bmi isolates phase plant ros scale ssp ratio pno pattern mechanism heterozygous migration cycle years diseases www
# ==================================================================================================
# cancer
#
# Topic 1, top 30 words:
# dysplasia anxa ews serrated hnscc peptide hgf cirrhosis diagnosis art patterns mortality sessile met endometrial atm hmga markers nls colorectal phenotype bhwe phosphorylation population scale pre pattern cirrhotic asct whole
#
# Topic 2, top 30 words:
# duxap muscle prcc ctcs rwpe art jam crc targeted ability prostate loci ihc brain hct weight area functional pre index hours ddp membrane common cytometry family upregulated tumours resistance huaier
#
# Topic 3, top 30 words:
# tert cisplatin hmga igg cxcr uchl leukemic pdx hcc bard tpe biomarker secondary resistance period mitochondrial grade tle membrane result nodules kinase ulk bhwe fluorescent collected conjugated phosphorylation intracellular efficacy
#
# Topic 4, top 30 words:
# rapa jam lsd hsa myb mirna jun socs lfnps tet detection fra coding rcc cntfr hcc brain reverse slca itraconazole kdma tpe melanoma probe plasma signal scale acf microscope asah
#
# Topic 5, top 30 words:
# ews cdcpli sodium bard lfnps hsa oleate rapa intracellular infected cox peptide hcc acf invasive kinase bhwe fli acid ability probe mortality years fra abcc nls biological next paln phenotype
#
# Topic 6, top 30 words:
# tdp tet lsd cpg peptide differentially socs ews biomarker paln pre whole phosphorylation change ctcs gbm difference extracted approach graph hsa ppi tat enrichment drugs tcp information mecp sesn targets
#
# Topic 7, top 30 words:
# dmdd dli vegf asct catechin early copper transduced lsd hcc subtypes dextran angiogenesis mecp mortality socs acid diagnostic weight reduction colorectal efficacy family paln diagnosis endothelial biomarker determine sesn together
#
# Topic 8, top 30 words:
# collagen ccn oscc nodules approach ppi prostate acid average alternative corresponding mirna melanoma expressing significance lumican added benign diagnosis hsa detection right bhwe hiv years myb tumours difference splicing viability
#
# Topic 9, top 30 words:
# mecp pno mdm arsenite prcc cdcpli sodium nahs right exposure whole extract average plasma vegf consistent hsa git profiles ctcs legend tdp oscc egcg socs infected tns left colon invasive
# ==================================================================================================
# plant-sciences
#
# Topic 1, top 30 words:
# bil dal pelleting glyphosate psii chl ssp repeats evolution furthermore lhcii combination smmyb trees primer diversity mutax presented cao release promoter lignin longan maximum photosynthetic main would bacterial unfolding nutrient
#
# Topic 2, top 30 words:
# circrnas prr carotenoid cdpk grapevine quantitative ripening mechanisms identification cold abiotic provide play hvcdpk gmtip top seedling metabolites stem tea moreover mapped rnai ethylene conducted bil extraction divergence promoter ghd
#
# Topic 3, top 30 words:
# npf food nitrate anthocyanin energy cas gas impact pvtat dietary tea crispr post uptake mutations fruits determine enzyme fungal amf vvtlp diet growing degradation wspc chl shoot locus pairs mainly
#
# Topic 4, top 30 words:
# osstrl qtls phenotypes hybrid maft maximum parlfs dataset main anther cas tyr male profiles density pairs spectra mutations mainly photosynthesis phyb ahg confirmed ratio photosynthetic metabolites negative pollfs period sterile
#
# Topic 5, top 30 words:
# anthocyanin amf fresh tapbs carotenoid cabbage cut biosynthetic pbs diversity density pre dpi chickpea anthocyanins growing grapevine discussion synthase npf conducted electron putative either demonstrated phosphate fruits cold range blue
#
# Topic 6, top 30 words:
# ssp eugenol phya efe afpa susceptible phyb anther antifungal encoding extraction fungal mediated lyrata synthase maximum post osstrl degradation ethylene tube wspc cut unigenes pbs nmn types included furthermore assay
#
# Topic 7, top 30 words:
# coumarin starch sqd darkness mediated stresses stressed abiotic confirmed prr relationship date whether kit loss ghd dependent combination strains www cold allele reduction tfs encoding ratio trihelix photosynthesis enhanced interactions
#
# Topic 8, top 30 words:
# dog maft vvtlp zdiii gaba gmpal fungal terminal ahg col organs dgwrky reaction hbcag assay diversity susceptible divergence transformed evolution pal rnai relationship growing cas accession ghd resulting combination play
#
# Topic 9, top 30 words:
# gig transition starch ssp complete association sugar gaba longan repeat npf cas lyrata svm osfh repeats qtls fhfh promoter nmn reaction cultivars trees actin quantitative accela images approximately enrichment gemmifera
# ==================================================================================================
# immunology
#
# Topic 1, top 30 words:
# nodes slt network salmonella irf nfkbiz shp puma typhimurium mait ethylene net hav period genetic median association minutes central efficacy enhanced since score malaria nets interestingly signal active protection severe
#
# Topic 2, top 30 words:
# aca artinm mixed bhb zdiii ntm arsenic rates parasites apoptosis saliva signal systemic modified university clones ana hbcag years five intestinal right protection recombinant pulmonary fluorescent interaction less types order
#
# Topic 3, top 30 words:
# mafb vegf plzf cre cgl efflux avium species interaction pkc ntm genotype tregs clic mif administered many gingivalis fibrosis bar domain parasites pixr gfp generation gondii score bladder top ability
#
# Topic 4, top 30 words:
# jak evs fish arsenic rag fed insulin ccp generation zdiii fraction ttll hypoxia average marker thrombin influenza hbcag evaluated targeting vaccination regulated inoculated applied developed amf hfd comparison change plates
#
# Topic 5, top 30 words:
# hcv arginine saliva oral ccp genetic types efficacy represent chronic included years genotype indicating pathways biofilm cgl active sodium phase comparison species manufacturers density plaque standard ilcs correlation huh scid
#
# Topic 6, top 30 words:
# smd naive cgl jak years resistant cre phosphorylation body mbt cxcl irf gfp pmvrp adamts result insulin plzf included muscle active minutes severe hav solution bars biofilm deficient damage critical
#
# Topic 7, top 30 words:
# ccp pregnant tregs mast mafb regulated innate peptides hbv ilcs insulin pkc marrow mbt sirt oxl enhanced ttll association carotid resistant interestingly spleen way major pathways manufacturers prior percentage molecules
#
# Topic 8, top 30 words:
# pixr mhe sirt clone cxcl network zdiii artinm eosinophils bhb fgf recombinant nodes mast types immunized influenza since burgdorferi would included administered manufacturers ptpb regulated molecules vaccination investigated tick dli
#
# Topic 9, top 30 words:
# cia bont sirna hca nanoparticles active gondii drug vaccination slt injury modified protection net clic major plates prior dpi zdiii mab mixed class complex ltbi nox even point many five
# ==================================================================================================
# chemical-biology
#
# Topic 1, top 30 words:
# elp ddr sensitivity sensitive dox pkn dyrkb myb rsv nucleotide jnj cis natural together spectrum hne mutation constructs furthermore matrix polymerase age sof aqueous tables factors modifications enrichment modified peg
#
# Topic 2, top 30 words:
# resveratrol tpe tle mtnfr lipids tnf tnfr cholesterol fluorescent cho sfgfp probe fusion dilution fraction hkme ligand secretion inhibitors kda ddr bars npc emission bar membranes metabolism investigated chia activated
#
# Topic 3, top 30 words:
# rqt quercetin cultures enac zinc glucoside rrm taste rqc responses klk injury ions pathways calhm minutes sham dyrkb constructs aggregation primer polymerase strand ribosome selected amiloride inflammatory tau heat experiment
#
# Topic 4, top 30 words:
# acs dcuk oet receptors gabaa sfgfp hne subunit oocytes open helix chains inflammatory subjects vivo extracellular channel available activated density elp secretion mutation clinical cad tables jnj natural efficiency spectrum
#
# Topic 5, top 30 words:
# ccp ttll ubch gli clc transcription ppar peg sigma stage notch oscc parkinsons stat quercetin ilcs metabolism polymerase ethylene srta tmelest average proliferation chilps dynamics early hkme extracellular enrichment constructs
#
# Topic 6, top 30 words:
# poglut udp egf sham dox sfgfp pheromone honey gli early injury actin kda plar loop termini regulation spectrum alarm pkn blot peg donor product gsk rage curve multiple honeys dark
#
# Topic 7, top 30 words:
# resveratrol rhbdl tumor heat metabolism pna peg constant mdp sfgfp probe crowding inha interestingly extracellular second dmdd bacterial product ubch directly ubp pathways channel helix simulations phosphate key tth agents
#
# Topic 8, top 30 words:
# strains promoter acs dimer ccp monomer spnfads cis average scale novel klf dcuk strain lipids additional ligand sirna transcription bond cultures simcells subunit irradiation weight interestingly sigma dynamics nucleotide artinm
#
# Topic 9, top 30 words:
# dyrkb plar dga primer pre sham plants ripc kda helix dimer artinm staining mutation starvation strain subunit spectrum bond honokiol promoter provide coa ectoine end early functional mnz inhibitors tnf
# ==================================================================================================
# chemistry
#
# Topic 1, top 30 words:
# udp spion wave leaves plant china chl pulse atoms poglut layers wscp mean nanoparticles selected egf pna correlation isolated furthermore exposure channel tmelest tested available direct acs surfaces soc solvent
#
# Topic 2, top 30 words:
# droplet surfaces myosin lipid direction actin plant expected rage composition constant buckled axis oxide bond transfer pna spion tension linear indicates led furthermore gqds thin glass mutants tested catalyst films
#
# Topic 3, top 30 words:
# dox ngo tio film sidt larger products flakes arsenic poly ciptec cholesterol image complexes buckled receptor exposed ubch pna exposure resulting involved mhz nanoparticles cycle cpeg error furthermore part diameter
#
# Topic 4, top 30 words:
# quercetin ruo glucoside dga vrk air starvation mnz myosin direction cavity force step actin rage layers constant tio image linear tissues washed nanoparticles extraction catalyst resulting ubch flies rfk conformation
#
# Topic 5, top 30 words:
# parkinsons tih prt sulfide complexes feo modes cyst exposure bacteria monomer sqr much thin arsenic iii lipids liver coli step raman responses white led silk moreover mutants constant eta selected
#
# Topic 6, top 30 words:
# vrk poly cultures elp acs sampling dox bta glass spnfads mnz tau boson arsenic tio terminal prilocaine ppm slice rhbdl brain dga isolated droplet pbs rfk thermal ngo sensitive bar
#
# Topic 7, top 30 words:
# phosphorylation elp actin angle stem tpe tle transfected pathway enac curve force priming mutants receptor sensitive additional pre responses bulge pbs ripc retinal upper films pathways major pure replication formed
#
# Topic 8, top 30 words:
# sham skin ripc pase ccp phosphorylation fatigue feo ttll pore pores day ilcs cyst atoms reperfusion tpe ubch bar amniotic tobacco work showing derived larger considered tested proton wave white
#
# Topic 9, top 30 words:
# noctiluca mnz ngo honey dox day biochar limited honeys metal proton complexes brain transfected tissues particles cellular feo stable hbv bond another cyst ability transfer isolated long dark lipid ruo
# ==================================================================================================
# evolution
#
# Topic 1, top 30 words:
# crispr cas calls longan call systems fixation bmdopr bacterial playback bsp fst phage white reaction dependent nuclear environment predictive proportion medium presented phenotype software suggesting experimental areas conserved bacteria hosts
#
# Topic 2, top 30 words:
# sinus rnas map stable equilibrium allometric linear nuclear moral remains slope lines condition hiv produced ratios bone alternative genbank neanderthal intercept presented segments generation types coi proportion provided limited admixture
#
# Topic 3, top 30 words:
# mcr cooperation diabetes nncrc south demographic forest structures variant activity remaining processes experiments receptor chr bacteria expansion genbank bsp characters southern containing discussion map partition association fish mouflon ecological class
#
# Topic 4, top 30 words:
# armillaria gbx bone sinus umbellatus tfs spring tripneustes coi consensus class characteristics ventral generation characters bsp genbank pairwise base node six dorsal signal applied helping reproductive nodes taxonomic summer shell
#
# Topic 5, top 30 words:
# ...
#
# Topic 4, top 30 words:
# rotor reflection residual variation retention weeks ghz nno condition pregnant corrosion calcium segmentation end ring microscopy errors self patients clinical feature another star still negative training application activity molecules taken
#
# Topic 5, top 30 words:
# rotor alo tube chf critical impact soil scaffolds regime catalyst boiling load four inner numerical soft main iii dynamics acfl interfacial end transition fields target activity states available controlled part
#
# Topic 6, top 30 words:
# knee implant cnt pixel frequencies oam cartilage previously motion microfluidic reconstruction antenna numerical related pdms relatively inside positive available modes load pbs additional droplets feasible self green healing demonstrate weight
#
# Topic 7, top 30 words:
# foam sio iii networks coil indicates patients residual crack cardiac feature graphene bar modes reconstruction patient temporal profile body ozone states dielectric quantum khz previously element application four evaporation part
#
# Topic 8, top 30 words:
# foam fracture pam meta terahertz dynamics interfacial mirror aperture crack ghz convex condition variations variation transition states pdms qwp relatively patterns micro qkd center weight wavelength selected gas sfi reflection
#
# Topic 9, top 30 words:
# microfluidic color pdms fiber subjects target body conductivity reflection coil fields pedot output inside end camera motion capillary droplets negative training damage period chamber soil application height recorded elastic networks
# ==================================================================================================
# materials-science
#
# Topic 1, top 30 words:
# dox heme ngo tendon meniscus pta boundary srvo fatigue acoustic electrochemical membranes detection organic unit zone shear good flakes crystals deformation left stem iron many fese velocity cpeg models equation
#
# Topic 2, top 30 words:
# ruo gqds leds led nanostructures phonon ectoine tem cuzr exchange mfm models photons ingan indicated content related previous treated xrd electrode lipid role components capacity pure according target selected force
#
# Topic 3, top 30 words:
# tio nbo gate electronic nps vortex needle unit composites positive limit considered width design dynamic metasurface incident frequencies resonant taken moreover according output sensing side right color electrode depth recently
#
# Topic 4, top 30 words:
# bise strength plasma ionic annealing illumination nbse tio constructs ion correlation nmr nanostructures tradd pure part printed feature capacity showing hydrogen silk metallic superconducting pyrroline curve tem features cellular fraction
#
# Topic 5, top 30 words:
# sampling boson stark echo exchange anisotropy furthermore shift discussed orientation phases gaussian taken propagation mass tem many stem ion controlled release detection magnetization either self vector evolution magnitude mean afm
#
# Topic 6, top 30 words:
# release spion smaller organic gel ruo lsmo relaxation self lipid hydrogen curve proton sites activity ectoine candle coupled electronic aqueous molecule elastic vector key limit sio theoretical experiment metallic ngo
#
# Topic 7, top 30 words:
# buckled proton silk magnetization pna solar part electrode pump depth good carried crystals negative bone speed photons composition generated anisotropy symmetry ref side mol amplitude concentrations ion electronic carbonate approximately
#
# Topic 8, top 30 words:
# ngo dox flakes pyrroline vivo release ruo mfm cpeg regime drop cellular anisotropy sites refractive nmr equilibrium grain color available impact highly additional micro metallic detection boundary dielectric nitrogen multiple
#
# Topic 9, top 30 words:
# silk plasma feedback vortex wall led hydrogel phases target across lens zno multiple related coupled magnetization dispersion refractive thz right flux mgzno nps srr lsmo smaller solutions incident proteins width
# ==================================================================================================
# nanoscience-and-technology
#
# Topic 1, top 30 words:
# fatigue grown pores pore aqueous components alo solutions hydrogen carried wire crack gqds afm deposited bulk elements grain annealing buffer tem individual sto chain mos sensing heat exhibit metallic achieved
#
# Topic 2, top 30 words:
# rotor pyrroline doping paper lipid vortex bilayer zno lsmo electrodes junction fepo lnmm release noise electrode antioxbens good coating seen ghz sensitivity upon added test afm mos electrical location buffer
#
# Topic 3, top 30 words:
# pores metallic glass phases conventional pyrroline orientation electrode metasurface critical close micro discussion previous clearly treated array human grain channel boundaries ola tradd led demonstrate boundary required weak defined elements
#
# Topic 4, top 30 words:
# dox ngo ectoine silver flakes plasmonic nanoparticle dielectric irradiation tlr cpeg human gold plasmon release monolayer illumination wavelengths thz green sirna analyzed afm models visible deposition hbv additional added typical
#
# Topic 5, top 30 words:
# helical metasurface gqd gqds negative trivial topological pna probes ref probability configuration paper coupled plasmonic waves qsh deposition elements wavelengths room correlations depth achieved deposited ion switching chiral dox ingan
#
# Topic 6, top 30 words:
# ingan inn hole tlr mls bulk lsmo pna defined helical alloy composition separation wall anisotropy buckled calculations silicon crystals tissue human clearly formed electrode required afm vortex close across initial
#
# Topic 7, top 30 words:
# probes cofe alignment helical paper key ola polarized silicon mos known vortex spion grown mass qkd mfm tem chain grain monolayer recently release fabrication frequencies right nuclear errors theoretical treated
#
# Topic 8, top 30 words:
# lsmo target electrode glass crystalline stable pss removal view configuration tem pedot feonhpd green across plasmon paper micro additional array bottom mass localized formed containing synthesized angles seen dashed flexible
#
# Topic 9, top 30 words:
# nps gqd doping anisotropy silica configuration glucose polymer wall depth dmc silver silk temperatures clearly tem channel application output human matrix onto defined right required metallic lsmo visible removal electrical
# ==================================================================================================
# drug-discovery
#
# Topic 1, top 30 words:
# dox lonicerae flos qsyq epha sites baseline mutant libraries intracellular conjugation peg performance library experiment tumour signature even ctc hbv lps wild peak second defined nanodrugs staining greater receptors frequency
#
# Topic 2, top 30 words:
# apoc epac rap mirnas mirna linear klf quercetin ability dogs hours lead amino metabolites spectra npc mhz variables cervical untreated connectivity indicate matrix western proliferation suggest fragment evaluation months tables
#
# Topic 3, top 30 words:
# oet dcuk receptors gabaa vrk dota gaba zegfr pna molecule rsv residues tumour linear uptake subunit ctc green prepared even rgs synthesis lead glut loop long crystal suggesting mitochondria scores
#
# Topic 4, top 30 words:
# midn tsn quercetin pna promoter stem schizophrenia glucoside molecule sites linear weight amino five second bacterial field conducted klf indicates ring administration indicate acids prt relationship apoc green right tumour
#
# Topic 5, top 30 words:
# honokiol neutrophils anxa hcc bard fpr zegfr dogs mirnas proliferation scores release profile fmlf hsa dota thrombosis invasion seq lncrna dmso western connectivity regulation components promoter intracellular months representative relationship
#
# Topic 6, top 30 words:
# retention snh device vrk isolated contrast connectivity tth enzyme meg crystal tsn als point conducted hla scores dms selection peak jnj perfusion lead wild mirna green urea lps long frequency
#
# Topic 7, top 30 words:
# hla bacterial zikv jnj infected heparanase rsv nbsl projects expressing qct residues selection inflammation receptors viral mutant rare larger dmso taken igg series rgs dms suggest asynchronous antibodies investigated library
#
# Topic 8, top 30 words:
# midn stem malaria zikv disorders promoter vaccine aqueous five specificity cis myosin pps discovery children infected irradiation hcv defined final signature conducted might solubilization involved ability raav approved mechanisms tables
#
# Topic 9, top 30 words:
# quercetin glucoside nps expansion rsv toxicity tgf mauveine panel quantified investigated primary sma western peg prediction mhz epha jnj synthesis migration spectra tumour acids times hours cohort long means antioxidant
# ==================================================================================================
# philosophy
#
# Topic 1, top 30 words:
# pgt consumers com minors diseases owed established linguistic basis law require www turn offer additional ngs basic consciousness empirical providers provision projects today perspective determine former models detailed essential muslim
#
# Topic 2, top 30 words:
# theatre ukk hermeneutical private light interior fictional csfs theatrical heidegger ifs never elements fascism particularly seems economic mean seen benefits suggests appropriate genocide described strategy perspective refer understood united samples
#
# Topic 3, top 30 words:
# transcendence seen event immanence turn acts object kantian hcps mysticism multitude essential views berardi faith action interior models economic central contemporary politics critique standard suggest autonomy nothing theological understood past
#
# Topic 4, top 30 words:
# heidegger benefits genocide identity contemporary kantian identification technologies greater fascism ssh critique answer theological funding hence structures projects national contrast options communication perspective hermeneutical suggest existing developed crisis effects calls
#
# Topic 5, top 30 words:
# samples neoliberal genotype responsible associated acts markets diseases ngs provides taken christ greater faith event pgt directly hope later http far past consumers appropriate seen professional traits neoliberalism children practices
#
# Topic 6, top 30 words:
# christ ifs hope stakeholder peace attitudes climate impact major deliberation ipcc cultural debate strategy stakeholders appropriate city additional views greater children act interaction instance associated national essential immanence class transcendence
#
# Topic 7, top 30 words:
# identity christ providers former kantian critique movement thoughts law seems elements existing environment believe practices markets reasons genotype economic described action external shakespeare realm taking diseases actual past belief perspective
#
# Topic 8, top 30 words:
# reasons deliberation aim principles ssh compromise funding external aims internal exist section standard identity controlled heinz multiple cognitive existence described climate understand whose size principle identification empirical united environmental instance
#
# Topic 9, top 30 words:
# greed faith ses recontact main unethical effects theological theatre interior importance replication event standard occurs size third law economic every sloterdijk laws provides advance national field interaction comes acts calls
# ==================================================================================================
# business-and-industry
#
# Topic 1, top 30 words:
# reconstruction motion acquisition elements tracking object fracture evaporation chf temporal retention reflection four depth illumination impact fiber color better dynamics boiling ray needle pedot pdms knee scan subjects clinical techniques
#
# Topic 2, top 30 words:
# foam graphene pam calcium knee rgo residual czts pbs load like back states corrosion sio condition nanostructured fiber sheets microfiber dmem dispersion nscs clinical limited pdms morphology directly inside software
#
# Topic 3, top 30 words:
# rotor residual star ghz foam terahertz tube friction soil dynamics note radius kpa qwp corrosion dmem smaller previously errors period precision modes chloride spectrum cellular sio numerical side critical weight
#
# Topic 4, top 30 words:
# pdms nno gelma conductivity activity containing load chloride prepared application boiling parylene pedot treated dmem jet available furthermore networks scaffolds damage bacteria weight controlled impact sio exposed viability center cnt
#
# Topic 5, top 30 words:
# etching feasible motion patients target feature classification pvdf condition patient antenna center pixel side pre demonstrate absorber networks color output depth subjects final segmentation wavelength many four related schematic tracking
#
# Topic 6, top 30 words:
# nds nbox training scheme nioy transition meta zno ion nbo boiling modes deposited gelma saturation pixel stability still feature elastic previously errors final convex relatively transport ncd delay estimated problem
#
# Topic 7, top 30 words:
# etching bar frequencies microfluidic gas operation nuss positive glucose charge mixture cnt self membranes index finite patients transport inside smaller sio numerical profile feature depth simulated ghz chamber short many
#
# Topic 8, top 30 words:
# fracture ncd dielectric transition activity profile pam component interfacial sheath crack subjects roughness external relatively dna self occurs aperture droplets calcium pre finally techniques directly classification formed regime foam previously
#
# Topic 9, top 30 words:
# crack reflection cox ncd droplets fracture transition raman taken load modes zno formed mirror pixel dielectric furthermore critical indicates spectra tube capillary mmp dynamics additional condition color pbs controlled like
# ==================================================================================================
# developmental-biology
#
# Topic 1, top 30 words:
# rpe cbl immune hesc mdx oocytes hne lacz long crc myocardium months constructs utrophin sinus meclozine semac trabecular oocyte msc muscles less comparison ratio skeletal numbers many acid female satellite
#
# Topic 2, top 30 words:
# ccl sca trophoblast tie netrin pcdh leydig elegans plasma vessel hat male life pericytes biofilm regeneration primitive mks nkx dufp morphology lacz eoma maturation injection irf exposure capacity female lifespan
#
# Topic 3, top 30 words:
# chro lifespan biofilm vgll erg evs mutants scfv immune aging elegans collateral new grown brain mitochondria contact capacity multiple life asxl value morphology targets fusion resulted dll worms fcs rat
#
# Topic 4, top 30 words:
# nanog dsh dyrka wing lif ptx mitochondria amniotic myricetin brain pak hbtscs sol mks elegans period state upon circadian netrin injection lepc nkx gal mechanism transcriptional cryopreserved students mefd vessel
#
# Topic 5, top 30 words:
# chro axin autophagy offspring immune mammary asxl smc met rat stat lacz ecs cirrhosis null ccp pcdh paqr circadian myo immunofluorescence male pregnancy period mutants hgf brown bat risk trophoblast
#
# Topic 6, top 30 words:
# mtp axl rmrp lesion contact erg hfe luciferase sirna ecm ecs populations mzf sites students ccp offspring normalized induce incubation smad sequences way bend axin upon ctr sequence numbers emt
#
# Topic 7, top 30 words:
# ndrg ccl evs angiogenesis ccp netrin primitive coup vegf signals brg added microarray axin differentiated coated mechanism tfii central subjected myocardium value invitrogen erythroblasts moreover hearts brdu tendon multiple expansion
#
# Topic 8, top 30 words:
# gig rgo floral gish transition fbxl syncytial nanostructured microfiber drosophila mdx shows testes period result comparison circadian rpe male differentiated gscs gbx express hair testis erg mitochondria dsh risk tsc
#
# Topic 9, top 30 words:
# vegf mtor lymphatic mecp axin lesion vessel dyrka exercise reporter vegfr domain coup twist erg irf jnk chro zebrafish tfii immunofluorescence exposure mks lacz methylation would acid brain mechanism direct
# ==================================================================================================
